# %%
import pickle
students = {'Student1':{'Name': 'Alice','Age': 18, 'Grade': 12},
            'Student2':{'Name': 'Alice1','Age': 17, 'Grade': 13},
            'Student3':{'Name': 'Alice2','Age': 19, 'Grade': 11},
            'Student4':{'Name': 'Alice3','Age': 16, 'Grade': 10}
           }

#file = open('Test.pkl','wb')
#pickle.dump(students,'Test.pkl')

with open('Test.pkl','wb') as f:
    pickle.dump(students,f)
    f.close

# %%
type(students)
# Out:
# dict
