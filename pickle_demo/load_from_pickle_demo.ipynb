# %%
import pickle

with open('Test.pkl','rb') as f:
    dataset_loaded = pickle.load(f)


print(dataset_loaded)
# Out:
# {'Student1': {'Name': 'Alice', 'Age': 18, 'Grade': 12}, 'Student2': {'Name': 'Alice1', 'Age': 17, 'Grade': 13}, 'Student3': {'Name': 'Alice2', 'Age': 19, 'Grade': 11}, 'Student4': {'Name': 'Alice3', 'Age': 16, 'Grade': 10}}

# %%
type(dataset_loaded)
# Out:
# dict
